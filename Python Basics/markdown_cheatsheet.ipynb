# %% [markdown]
# # Markdown Cheatsheet
# ## 1- Headings
# How to give headings in markdown?
#
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6
# #### so on...
#
# ## 2- Block of words
#
#  Normal Text in Markdown.
#
#  >Special Text
#  >
#  >Second line
#
# ## 3- Line breaks
#
# This is to check breaks in line
#
# Second line goes
#
#  or
#
# This is to check breaks in line\
# Second line goes
#
# ## 4- Combine two things
#
# block of words and heading
#
# >## H2
#
# ## 5- Text Face
#
# **Bold**
#
# *Italic*
#
# ***Bold and Italic***
#
# or
#
# __Bold__
#
# _Italic_
#
# ___Bold and Italic___
#
#
# ## 6- Bullet
#
# 1. First ordered list item
# 2. Another item
#   * Unordered sub-list.
# 1. Actual numbers don't matter, just that it's a number
#   1. Ordered sub-list
# 4. And another item.
#
#    Some text that should be aligned with the above item.
#
# * Unordered list can use asterisks
# - Or minuses
#    - sub bullet
#      - sub sus bullet
# + Or pluses
#
#
# ## 7- Line/page breaks
#
# This is page 1
#
# ---------
# _________
#
# ***********
#
# Second Page
#
# ## 8- Links and HyperLinks
#
#
# Reference-style:
# ![alt text][logo]
#
# [logo]: https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 2"
#
#
# Here's our [logo][logo].
#
#
# ## Commenting in Markdown
#  <!-- - Ctrl+K+C for commenting  -->
#  - Ctrl+K+U for uncommenting
#
# ## 9- Figure links
#
# Inline-style:
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 1")
#
#
# ## 10- Adding code/code blocks
#
# To print a string `print("Codanics")`'
#
# `print("Python")`'
#
# To write different language codes with colors according to their syntax
#
# ```python
# print("Python")
# x+y=5
# x=7
# ```
#
# ```R
# print("Python")
# x+y=5
# x=7
# ```
#
# ## 11- Tables
#
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | col 3 is      | right-aligned | $1600 |
# | col 2 is      | centered      |   $12 |
# | zebra stripes | are neat      |    $1 |
#
# The outer pipes (|) are optional, and you don't need to make the raw Markdown line up prettily. You can also use inline Markdown.
#
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3
#
#
# ## 12- Mathematical Equations
#
# Good reference is MAthJax for mathematical equations syntax
# Here are some examples to try out:
#
# $$-b \pm \sqrt{b^2 - 4ac} \over 2a$$
#
# $$x = a_0 + \frac{1}{a_1 + \frac{1}{a_2 + \frac{1}{a_3 + a_4}}}$$
#
# $$\forall x \in X, \quad \exists y \leq \epsilon$$
#
# The beginning and ending dollar signs ($) are the delimiters for the TeX markup.
#
# You can also $add_{math}$ and
#
# $$
# math^{blocks}
# $$
#
# But make sure you \$Escape \$your \$dollar signs \$you want to keep!
#
#
# ## 13- Table of Content
#
# [Headings](#1--headings) \
# [Block of words](#2--block-of-words)\
# [Line breaks](#3--line-breaks)\
# [Combine two things](#4--combine-two-things)\
# [Text Face](#5--text-face)\
# [Bullets](#6--bullet) \
# [Line/page breaks](#7--linepage-breaks)\
# [Links and Hyperlinks](#8--links-and-hyperlinks)\
# [Figure links](#9--figure-links)\
# [Adding code/code blocks](#10--adding-codecode-blocks)\
# [Tables](#11--tables)\
# [Mathematical Equations](#12--mathematical-equations)
#
# ## 14- Install Extensions
#
# 1. Markdown All in One
# 2. Markdown PDF
# 3. MMarkdown Shortcuts
# 4. markdownlint
